# %%
import pandas as pd
import os

# %%
pwd = os.getcwd()
filepath = pwd + "\\windows_store.csv"

# %%
msc_csv = pd.read_csv(filepath, nrows=20)
msc_csv
# Out:
#                                                  Name Price  \
# 0                                    WhatsApp Desktop  Free
# 1                                    Telegram Desktop  Free
# 2                      Amazon Prime Video for Windows  Free
# 3                                           Instagram  Free
# 4                                       Spotify Music  Free
# 5                                             Netflix  Free
# 6                                             VLC UWP  Free
# 7                                          Your Phone  Free
# 8                                              iTunes  Free
# 9                                          Python 3.9  Free
# 10                                   Lively Wallpaper  Free
# 11                                    Adobe Lightroom  Free
# 12                                           Facebook  Free
# 13                                       Dolby Access  Free
# 14                                              Alexa  Free
# ...

# %%
#app/game description to classify their categories
app_cat = msc_csv.iloc[0: ,[2,5]]
app_cat
# Out:
#                                           Description  \
# 0   With WhatsApp on the desktop, you can seamless...
# 1   Pure instant messaging — simple, fast, secure,...
# 2   Watch movies and TV shows recommended for you,...
# 3   Bringing you closer to the people and things y...
# 4   Love music? Play your favorite songs and album...
# 5   Netflix has something for everyone. Watch TV s...
# 6   VLC is the ultimate media player, ported to th...
# 7   You love your phone. So does your PC. Get inst...
# 8   iTunes is the easiest way to enjoy everything ...
# 9   Python is an easy to learn, powerful programmi...
# 10  Free and open-source application for setting G...
# 11  * A qualifying Adobe Photoshop Lightroom subsc...
# 12  The Facebook app helps you connect with friend...
# 13  Download Dolby Access to start your free trial...
# 14  The convenience of Alexa, now on your PC \r\n\...
# 15  With the Amazon Music app you get access to mi...
# ...

# %%
#app/game description to classify their age rating
app_age = msc_csv.iloc[0: , [2, 7]]
app_age
# Out:
#                                           Description          Age Rating
# 0   With WhatsApp on the desktop, you can seamless...   For ages 3 and up
# 1   Pure instant messaging — simple, fast, secure,...  For ages 18 and up
# 2   Watch movies and TV shows recommended for you,...  For ages 12 and up
# 3   Bringing you closer to the people and things y...  For ages 12 and up
# 4   Love music? Play your favorite songs and album...  For ages 12 and up
# 5   Netflix has something for everyone. Watch TV s...  For ages 12 and up
# 6   VLC is the ultimate media player, ported to th...   For ages 3 and up
# 7   You love your phone. So does your PC. Get inst...   For ages 3 and up
# 8   iTunes is the easiest way to enjoy everything ...  For ages 12 and up
# 9   Python is an easy to learn, powerful programmi...   For ages 3 and up
# 10  Free and open-source application for setting G...   For ages 3 and up
# 11  * A qualifying Adobe Photoshop Lightroom subsc...   For ages 3 and up
# ...

# %%
#Analysis of writing styles of description of different apps
app_desc = msc_csv.iloc[0: , [0, 2]]
app_desc
# Out:
#                                                  Name  \
# 0                                    WhatsApp Desktop
# 1                                    Telegram Desktop
# 2                      Amazon Prime Video for Windows
# 3                                           Instagram
# 4                                       Spotify Music
# 5                                             Netflix
# 6                                             VLC UWP
# 7                                          Your Phone
# 8                                              iTunes
# 9                                          Python 3.9
# 10                                   Lively Wallpaper
# 11                                    Adobe Lightroom
# 12                                           Facebook
# 13                                       Dolby Access
# 14                                              Alexa
# 15                                       Amazon Music
# ...

# %%
#Analysis of size of apps/games from different categories
app_size = msc_csv.iloc[0: , [5, 6]]
app_size
app_size.groupby("Category")["Size"].count().reset_index()
# Out:
#                                        Category  Size
# 0          Developer tools  >  Development kits     1
# 1                                 Entertainment     4
# 2                                         Music     3
# 3  Personalization  >  Wallpaper & lock screens     1
# 4                                 Photo & video     3
# 5                                  Productivity     4
# 6                                        Social     4

# %%
#Analyse the differences between popular apps and other apps
