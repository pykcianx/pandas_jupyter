# %%
import pandas as pd
import os

# %%
pwd = os.getcwd()
filepath = pwd + "/avocado.csv"

# %%
avocadocsv = pd.read_csv(filepath)
avocadocsv
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0               0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1               1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2               2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3               3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4               4  2015-11-29          1.28      51039.60   941.48   43838.39
# ...           ...         ...           ...           ...      ...        ...
# 18244           7  2018-02-04          1.63      17074.83  2046.96    1529.20
# 18245           8  2018-01-28          1.71      13888.04  1191.70    3431.50
# 18246           9  2018-01-21          1.87      13766.76  1191.92    2452.79
# 18247          10  2018-01-14          1.93      16205.22  1527.63    2981.04
# 18248          11  2018-01-07          1.62      17489.58  2894.77    2356.13
#
# ...

# %%
avocadocols = avocadocsv.iloc[0:, [3, 12]]
avocadocols
# Out:
#        Total Volume  year
# 0          64236.62  2015
# 1          54876.98  2015
# 2         118220.22  2015
# 3          78992.15  2015
# 4          51039.60  2015
# ...             ...   ...
# 18244      17074.83  2018
# 18245      13888.04  2018
# 18246      13766.76  2018
# 18247      16205.22  2018
# 18248      17489.58  2018
#
# [18249 rows x 2 columns]

# %%
#AVOCADOCALYPE IN 2017 WAS REAL!

avocadocols.groupby("year")["Total Volume"].count().reset_index()
# Out:
#    year  Total Volume
# 0  2015          5615
# 1  2016          5616
# 2  2017          5722
# 3  2018          1296

# %%
#COUNTRY WITH LOWEST PRICES OF AVOCADO

#avocadocols = avocadocsv.iloc[0:, [2, 13]]
#avocadocols.groupby("region")["AveragePrice"].count().reset_index()
#commentsss
